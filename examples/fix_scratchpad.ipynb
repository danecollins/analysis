# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in cycling data
df = pd.read_json('data/cycling.json')
df.head(2)
# Out:
#             FX 7.5  BB  BMC  S2016  S2017  FX 7.7  C3  Surly  Other  \
# 2024-01-30     NaN NaN  NaN    NaN    NaN     NaN NaN   11.7    NaN
# 2024-01-29     NaN NaN  NaN    NaN    NaN     NaN NaN   15.3    NaN
#
#            Day of week Notes
# 2024-01-30     Tuesday
# 2024-01-29      Monday

# %%
df_new = df.replace('Thusday', 'Thursday')

# %%
df_new.to_json('data/cycling.json')

# %%
df_new['Total'] = df.drop(columns=['Day of week', 'Notes']).sum(axis='columns')

# %%
df_new.head()
# Out:
#             FX 7.5  BB  BMC  S2016  S2017  FX 7.7  C3  Surly  Other  \
# 2024-01-30     NaN NaN  NaN    NaN    NaN     NaN NaN   11.7    NaN
# 2024-01-29     NaN NaN  NaN    NaN    NaN     NaN NaN   15.3    NaN
# 2024-01-25     NaN NaN  NaN    NaN    NaN     NaN NaN   20.8    NaN
# 2024-01-24     NaN NaN  NaN    NaN    NaN     NaN NaN    7.6    NaN
# 2024-01-19     NaN NaN  NaN    NaN   11.1     NaN NaN    NaN    NaN
#
#            Day of week  Notes  Total
# 2024-01-30     Tuesday          11.7
# 2024-01-29      Monday          15.3
# 2024-01-25    Thursday          20.8
# 2024-01-24   Wednesday           7.6
# 2024-01-19      Friday  Zwift   11.1

# %%
df_new.to_json('data/cycling_w_total.json')
