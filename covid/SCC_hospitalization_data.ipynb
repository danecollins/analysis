# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('http://data.sccgov.org/resource/5xkz-6esm.csv')
df.head()
# Out:
#                       date  icu_covid  icu_pui  icu_other  icu_available  \
# 0  2020-03-27T00:00:00.000         63       22        NaN             66
# 1  2020-03-28T00:00:00.000         30       66        NaN             87
# 2  2020-03-29T00:00:00.000         69       13        NaN             91
# 3  2020-03-30T00:00:00.000         72       34        NaN             68
# 4  2020-03-31T00:00:00.000         73       19        NaN             73
#
#    non_icu_covid  non_icu_pui  non_icu_other  non_icu_available  vents_pts  \
# 0             62           52            NaN                293         95
# 1            111           28            NaN                403         90
# 2             81           49            NaN                549        115
# 3             82           74            NaN                579        110
# 4             76           68            NaN                630        107
#
#    ...  pui_total  covid_pct_7davg  covid_pui_pct_7davg  icu_covid_pct_7davg  \
# 0  ...         74              NaN                  NaN                  NaN
# 1  ...         94              NaN                  NaN                  NaN
# 2  ...         62              NaN                  NaN                  NaN
# 3  ...        108              NaN                  NaN                  NaN
# 4  ...         87              NaN                  NaN                  NaN
#
#    icu_covid_pui_pct_7davg  non_icu_covid_pct_7davg  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#    non_icu_covid_pui_pct_7davg  cap_all  cap_icu  cap_non_icu
# 0                          NaN    0.643    0.437        0.720
# 1                          NaN    0.676    0.475        0.744
# 2                          NaN    0.751    0.526        0.809
# 3                          NaN    0.712    0.391        0.788
# 4                          NaN    0.749    0.442        0.814
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['date', 'icu_covid', 'icu_pui', 'icu_other', 'icu_available',
#        'non_icu_covid', 'non_icu_pui', 'non_icu_other', 'non_icu_available',
#        'vents_pts', 'vents_available', 'ped_covid_pui', 'ped_icu_beds',
#        'covid_new', 'covid_total', 'pui_total', 'covid_pct_7davg',
#        'covid_pui_pct_7davg', 'icu_covid_pct_7davg', 'icu_covid_pui_pct_7davg',
#        'non_icu_covid_pct_7davg', 'non_icu_covid_pui_pct_7davg', 'cap_all',
#        'cap_icu', 'cap_non_icu'],
#       dtype='object')

# %%
df.icu_available.plot()

# %%
df.covid_total.plot()

# %%
df_city = pd.read_json('http://data.sccgov.org/resource/59wk-iusg.json')
df_city.sort_values('rate', ascending=False)
# Out:
#     geo_id             city  cases  population   rate
# 2   629504           Gilroy    439       55525  791.0
# 12  668000         San Jose   5407     1026658  527.0
# 8   649278      Morgan Hill    205       43876  467.0
# 7   648956     Monte Sereno     15        3492  430.0
# 0   610345         Campbell    172       42470  405.0
# 13  669084      Santa Clara    425      126209  337.0
# 15  677000        Sunnyvale    404      152323  265.0
# 6   647766         Milpitas    191       77457  247.0
# 5   644112        Los Gatos     72       30922  233.0
# 3   643280        Los Altos     64       30588  209.0
# 11  655282        Palo Alto    138       67019  206.0
# 9   649670    Mountain View    166       80993  205.0
# 4   643294  Los Altos Hills     16        8517  188.0
# 14  670280         Saratoga     49       30886  159.0
# 1   617610        Cupertino     62       60614  102.0
# 10       0    Other/Unknown    496           0    NaN

# %%
df_city[df_city.city == 'Campbell']
# Out:
#    geo_id      city  cases  population   rate
# 0  610345  Campbell    172       42470  405.0
