# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('http://data.sccgov.org/resource/5xkz-6esm.csv')
df.iloc[-1]
# Out:
# date                           2020-12-19T00:00:00.000
# icu_covid                                          128
# icu_pui                                              3
# icu_other                                          168
# icu_available                                       37
# non_icu_covid                                      470
# non_icu_pui                                         18
# non_icu_other                                     1193
# non_icu_available                                  296
# vents_pts                                          239
# vents_available                                    491
# covid_new                                          106
# covid_total                                        608
# pui_total                                           21
# covid_total_7davg                              562.429
# pui_total_7davg                                23.4286
# covid_pct_7davg                                   0.25
# ...

# %%
df.columns
# Out:
# Index(['date', 'icu_covid', 'icu_pui', 'icu_other', 'icu_available',
#        'non_icu_covid', 'non_icu_pui', 'non_icu_other', 'non_icu_available',
#        'vents_pts', 'vents_available', 'covid_new', 'covid_total', 'pui_total',
#        'covid_total_7davg', 'pui_total_7davg', 'covid_pct_7davg',
#        'covid_pui_pct_7davg', 'other_total', 'available_total',
#        'icu_covid_pct_7davg', 'icu_covid_pui_pct_7davg',
#        'non_icu_covid_pct_7davg', 'non_icu_covid_pui_pct_7davg',
#        'cap_pct_7davg_total', 'icu_cap_pct_7davg', 'non_icu_cap_pct_7davg'],
#       dtype='object')

# %%
df.icu_available.plot()

# %%
df.covid_total.plot()

# %%
df.non_icu_available.plot();

# %%
df_city = pd.read_json('http://data.sccgov.org/resource/59wk-iusg.json')
df_city.sort_values('rate', ascending=False)
# Out:
#     geo_id             city  cases  population    rate
# 2   629504           Gilroy   3915       55525  7051.0
# 8   649278      Morgan Hill   1702       43876  3879.0
# 12  668000         San Jose  37128     1026658  3616.0
# 0   610345         Campbell   1004       42470  2364.0
# 6   647766         Milpitas   1579       77457  2039.0
# 13  669084      Santa Clara   2411      126209  1910.0
# 9   649670    Mountain View   1450       80993  1790.0
# 5   644112        Los Gatos    538       30922  1740.0
# 15  677000        Sunnyvale   2373      152323  1558.0
# 7   648956     Monte Sereno     50        3492  1432.0
# 3   643280        Los Altos    333       30588  1089.0
# 4   643294  Los Altos Hills     88        8517  1033.0
# 11  655282        Palo Alto    680       67019  1015.0
# 14  670280         Saratoga    288       30886   932.0
# 1   617610        Cupertino    355       60614   586.0
# 10       0    Other/Unknown   2440           0     NaN

# %%
df_city[df_city.city == 'Campbell']
# Out:
#    geo_id      city  cases  population   rate
# 0  610345  Campbell    172       42470  405.0
