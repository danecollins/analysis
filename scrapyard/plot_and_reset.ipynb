# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

from pertest.util import *
from pertest.models import Test, Metric

# %%
# django setup
os.environ['DATABASE_URL'] = 'postgres://awrdbuser:sjsharks@awrdata-prod.czjbjfomv0k0.us-west-2.rds.amazonaws.com:5432/awrdata'
sys.path.append('/users/dane/src/datatools/analytics/')
# Out:
# 8

# %%
plot_df(get_df(failed_list))
