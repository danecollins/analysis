# %% [markdown]
# # Eigenvalue Study

# %%
# standard imports from Dane's example

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# import particular to reading files
import xlrd  # reading for excel files

# %%
# Note path names with back-slashes in them need to be escaped
# You should be able to go to any public network share.  Note this is running
# as the user dcollins so it cannot access private shares

data = np.loadtxt(r'\\us-els-argo\awr\Share\EC folders\Dane\data\Eig_sysPinvZ_2.txt')
data
# Out:
# array([[ 2.87989e+00,  1.18205e-01],
#        [ 2.51461e+00,  2.10129e-02],
#        [ 2.34747e+00,  2.49341e-02],
#        ...,
#        [ 9.76295e-01,  2.28884e-05],
#        [ 9.77523e-01, -3.45327e-04],
#        [ 9.75839e-01, -3.72876e-04]])

# %%
x = data[:,0]
y = data[:,1]
x
# Out:
# array([2.87989 , 2.51461 , 2.34747 , ..., 0.976295, 0.977523, 0.975839])

# %%
fig, ax = plt.subplots()
ax.plot(x, y, '+', color='black');
ax.set(xlabel='Real', ylabel='Imag',
       title='Eigenvalues')
ax.grid()
plt.show()

# %% [markdown]
# Note that at 2GHz, GMRES took 28 iterations
