# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [16,12]
import dtutil.configs as dtc
import glob

# %%
df = pd.read_csv('/Users/dane/data/a/perf/metric_sample_data/train_10243.csv')
df.head()
# Out:
#      build             type structure                         project  \
# 0  9603.01  AxPerf:Memory$M      A1a2  Ax_via_overlap_thin_metal_A1xx
# 1  9603.02  AxPerf:Memory$M      A1a2  Ax_via_overlap_thin_metal_A1xx
# 2  9603.05  AxPerf:Memory$M      A1a2  Ax_via_overlap_thin_metal_A1xx
# 3  9603.09  AxPerf:Memory$M      A1a2  Ax_via_overlap_thin_metal_A1xx
# 4  9603.11  AxPerf:Memory$M      A1a2  Ax_via_overlap_thin_metal_A1xx
#
#      value  failure
# 0  87.1094        0
# 1  86.6641        0
# 2  86.5508        0
# 3  86.6797        0
# 4  86.0938        0

# %%
fig = plt.gcf()
fig.set_size_inches(18,8)
plt.plot(df.value)
plt.scatter(x=df.index, y=df.value, c='blue', s=10)
failures = df[df.failure==1]
plt.scatter(x=failures.index, y=failures.value, c='red', s=40)
r = df.iloc[0]
title = f"{r.type} - {r.project} / {r.structure}"
plt.ylabel('Time (s)')
plt.title(title);
