# %% [markdown]
# # Getting Started with the Featured DataFrame
#
# When looking at telemetry data there are 2 representations of the data.  The first is the raw session based telemetry data.  The second, which this notebook will describe, contains each user-week with feature columns.
#
# First, let's start with our standard imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
import dtutil.configs as dtc  # import the datatools config variables
from helper import get_name_and_company

# %% [markdown]
# Next, we need to load in the feature file.  This file has one row for each user-week and a column for each feature in addition to information describing the user-week.

# %%
df = pd.read_csv(dtc.paths.tlm_uwdata_file)  # this is the path to the features file
df.columns
# Out:
# Index(['Unnamed: 0', 'HB_aplac_b', 'HB_legacy_b', 'add_measurement_b',
#        'add_mwo_elem_b', 'add_sim_doc_b', 'add_vss_elem_b', 'ana_doc_b',
#        'ana_sim_n', 'annotation_b', 'antenna_b', 'bindkeys_b',
#        'board_import_b', 'cell_stretchers_b', 'commands_n', 'company',
#        'create_process_b', 'disp_name', 'doc_sets_b', 'drc_b', 'ele_created_n',
#        'em_sim_b', 'ems_doc_b', 'ems_highcnt_b', 'ems_sim_n',
#        'enable_disable_b', 'envelope_sim_b', 'extract_b',
#        'floating_load_pull_b', 'freeze_traces_b', 'gen_poly_b', 'ifilter_b',
#        'insert_window_b', 'job_rich_text_b', 'job_scheduler_b', 'layout_b',
#        'layout_checks_b', 'lin_noise_b', 'lin_sim_n', 'load_pull_b',
#        'load_pull_script_b', 'lvs_b', 'markers_b', 'measurements_n',
#        'network_synthesis_b', 'new_HB_meas_b', 'no_sim_b', 'nonlin_sim_n',
#        'optim_b', 'osc_b', 'output_eq_b', 'pcb_improved_clipping_b',
#        'pcb_point_ports_b', 'pcb_shape_flow_b', 'pdk_b', 'phased_array_b',
#        'project_import_b', 'radar_b', 'remote_analyst_n', 'remote_axiem_n',
#        'schematic_eq_b', 'script_ide_b', 'scripts_b', 'sim_filters_b',
#        'stability_b', 'switch_lists_b', 'symbol_gen_b', 'transient_b',
#        'tuning_b', 'user_folder_b', 'user_id', 'user_type', 'vss_doc_b',
#        'vss_rfb_b', 'vss_rfi_b', 'vss_rfp_b', 'vss_sim_n', 'week', 'xem_doc_b',
#        'xem_sim_n', 'xmodels_b', 'yield_b', 'activity', 'scope'],
#       dtype='object')

# %% [markdown]
# ### Column Description
#
# The columns which are features will end in '_n' or '_b' depending on whether they represent counts (the count of the operation for the user-week) or just boolean flags (0 or 1).  In addition to these, we have the derived features of activity and scope.
#
# Descriptive columns, which don't represent features, include week, user_id, user_type, company and disp_name.
#
# #### Week
#
# The week is an integer representation of the week where the last 2 digits are the week number (0-51) and the beginning digits are (year - 2010) so 803 is the 4th week of 2018.
#
# #### User Type
#
# The user type is determined by serial number and can be internal, academic, demo, customer, pirate and licensed.  Licensed represents non-AWR NI users.
#
# ### Analyzing the Data
#
# ##### Filtering
#
# One of the most common tasks will be filtering the data

# %%
# just keep 2018 so we have 1 year of data
df2018 = df[(df.week >= 800) & (df.week < 900)]

# filter out internal users
external_df = df2018[df2018.user_type != 'internal']

# %% [markdown]
# The simplest way to filter a dataframe is to create a boolean vector and then subset the dataframe using square brackets.  In the first example we take the column user_type and compare it to 'internal'.  This will perform the comparison on each row of the dataframe and return a vector (actually a series) of the results.  When we pass this to the indexing function (the square brackets) it will return a new dataframe containing only the rows where the vector is True.
#
# In the second example, we are actually creating two series, performing an and between them and then passing that result to the indexer.  Note when doing this I've found parenthesis are required to get the right order of operations.
#
# ##### Getting Unique Values

# %%
# Get all the user_types
df2018.user_type.unique()
# Out:
# array(['internal', 'customer', 'licensed', 'academic', 'pirate', 'demo',
#        'loan', 'unknown'], dtype=object)

# %%
# or get them with counts (# user-weeks)
df2018.user_type.value_counts()
# Out:
# customer    23390
# academic    22491
# pirate      10945
# demo         3104
# internal     2730
# licensed     1056
# loan          283
# unknown         4
# Name: user_type, dtype: int64

# %%
user_weeks_by_user = external_df.user_id.value_counts()
len(user_weeks_by_user)
# Out:
# 11320

# %%
# wow, that's a lot, how many have only 1 or 2 user-weeks
print('Number of casual users:', len(user_weeks_by_user[user_weeks_by_user < 3]))
print('Number of heavy users:', len(user_weeks_by_user[user_weeks_by_user > 26]))
# Out:
# Number of casual users: 5629
# Number of heavy users: 358

# %%
for user_id, count in user_weeks_by_user[user_weeks_by_user > 50].iteritems():
    n, c = get_name_and_company(external_df, user_id)
    print('{:3d} - {}, {} ({})'.format(count, c, n, user_id))
# Out:
#  53 - Friends, nan (1399)
#  53 - Werlatone, Inc. - Patterson, Mariama Barrie @ Werlatone (1023)
#  53 - Qualcomm Technologies, Inc. - Headquarters, Qualcomm Technologies, Inc. - Headquarters (15926)
#  53 - USER, Pirate No user name (963)
#  53 - Qualcomm Technologies, Inc. - Headquarters, nan (11420)
#  53 - Qorvo - Osaka, nan (6574)
#  52 - Arizona State University - School of Earth and Space Exploration, HAMDI MANI (799)
#  52 - Qualcomm Technologies, Inc. - Headquarters, nan (11408)
#  51 - Akoustis, Inc., nan (1352)
#  51 - National Instruments - Santa Rosa, Justin Majers @ NISR (350)
#  51 - Qorvo - TQ Apopka, Aziz Alakan @ Qorvo FL (1048)
#  51 - Qorvo - TQTX IDP Richardson, Scott Schafer @ Qorvo (363)
#  51 - Qualcomm Technologies, Inc. - Headquarters, nan (11460)
#  51 - Qualcomm Technologies, Inc. - Headquarters, nan (11301)
#  51 - Qualcomm Technologies, Inc. - Headquarters, nan (11171)
#  51 - Qorvo - TQ Apopka, Hailing Yue? at Qorvo FL (742)

# %% [markdown]
# Let's explain this a little more.  When we do a value_counts() we get back a series.  Think of this as a two column table where the first column is the user_id and the second column is the count.  When we compare this to a value as in:
# ```
# user_weeks_by_user < 3
# ```
# we get back a vector or boolean values which we can then use to filter the series as we did in the dataframe.

# %% [markdown]
# ### Tips and Tricks
#
# Because there are some operations that are pretty common I've created some functions to help simplify the code for them such as get_name_and_company().  For example if we want to count the number of user weeks for uses of the phased array feature we could use

# %%
cust2018 = df[(df.user_type == 'customer') & (df.week >= 800) & (df.week < 900)]
pharr_use = cust2018.groupby(['user_id']).phased_array_b.sum()
pharr_use[pharr_use > 1]

print('cnt  Company, User')
for user_id, count in pharr_use[pharr_use > 1].iteritems():
    n, c = get_name_and_company(cust2018, user_id)
    print('{:3d} - {}, {} ({})'.format(count, c, n, user_id))
# Out:
# cnt  Company, User
#   3 - Syrlinks, Simon Mener @ Syrlinks (678)
#   2 - SARAS Technology Limited, nan (11832)
#   2 - Qorvo - TQTX IDP Richardson, nan (13209)
#   2 - Oculus/Facebook, nan (16234)
#   3 - Dynetics, nan (16994)
#   2 - Konkuk University - Electronic Engineering, nan (17395)
#   3 - Konkuk University - Electronic Engineering, nan (17854)

# %% [markdown]
# ### Features
#
# Here is how you get the description of all the feature columns.  In order to load in the featuring code, we need to set the system path to add the directory the file is in.

# %%
import sys
sys.path.append('\\src\\datatools\\ipy\\notebooks\\session_data\\dev')
from features import define_feature

# %%
define_feature.print_docs()
# Out:
# ele_created_n not in pct
#
#  1 - ele_created_n
#      Defined as: Number of elements created
#                : Counts the number of MWOElement and VSSElement with the new tag
# commands_n not in pct
#
#  2 - commands_n
#      Defined as: Number of commands executed
#                : Sums the total count on all items in the Command category
# no_sim_b not in pct
#
#  3 - no_sim_b
#      Defined as: Contain no simulations
#                : True if there are no items in the Simulate category
# lin_sim_n not in pct
#
#  4 - lin_sim_n
#      Defined as: Linear Simulation Count
#                : Count of the LinCktSimAWR, Default Linear and APLAC Linear items
# nonlin_sim_n not in pct
#
#  5 - nonlin_sim_n
#      Defined as: Nonlinear Simulation Count
#                : Count of all HB, AC, stability, transient (including HSPICE) simulations
# HB_legacy_b not in pct
#
#  6 - HB_legacy_b
#      Defined as: Uses legacy HB simulator
#                : True if HB legacy or AC-HB legacy simulations have been run
# new_HB_meas_b not in pct
#
#  7 - new_HB_meas_b
#      Defined as: New HB measurement
#                : True is a new HB measurement has been added
# HB_aplac_b not in pct
#
#  8 - HB_aplac_b
#      Defined as: Uses Aplac HB simulator
#                : True if Aplac HB or AC-HB simulation is run.
# transient_b not in pct
#
#  9 - transient_b
#      Defined as: Uses transient simulator
#                : True if HSPICE or Aplac transient simulation is run.
# em_sim_b not in pct
#
# 10 - em_sim_b
#      Defined as: Has EM simulation
#                : True if Axiem, Analyst EMSight, Sonnet, Ansys or unknown EM simulation is run.
# load_pull_b not in pct
#
# 11 - load_pull_b
#      Defined as: Has load-pull measurements
#                : True if load pull measurement is found in project.
# load_pull_script_b not in pct
#
# 12 - load_pull_script_b
#      Defined as: Used load-pull script
#                : True if a load pull script "Load_Pull.*" has been executed.
# xmodels_b not in pct
#
# 13 - xmodels_b
#      Defined as: Has XModel elements
#                : True if any X or X$ model is found in the project.
# ems_highcnt_b not in pct
#
# 14 - ems_highcnt_b
#      Defined as: Sessions with large EMSight sim counts
#                : True if the session has more than 100 EMSight simulations (possible x-model fill).
# ems_doc_b not in pct
#
# 15 - ems_doc_b
#      Defined as: Has EMSight document
#                : True if there is an EMSight document.
# ems_sim_n not in pct
#
# 16 - ems_sim_n
#      Defined as: EMSight simulation count
#                : Number of EMSight simulations.
# vss_doc_b not in pct
#
# 17 - vss_doc_b
#      Defined as: Has a system diagram
#                : True if there is a system diagram in project.
# vss_sim_n not in pct
#
# 18 - vss_sim_n
#      Defined as: VSS TD simulation count
#                : Number of VSS time domain simulations in session.
# vss_rfi_b not in pct
#
# 19 - vss_rfi_b
#      Defined as: VSS RF Inspector
#                : True if there is an RF inspector simulation.
# vss_rfb_b not in pct
#
# 20 - vss_rfb_b
#      Defined as: VSS RF Budget
#                : True of there is an RF budget analysis.
# vss_rfp_b not in pct
#
# 21 - vss_rfp_b
#      Defined as: VSS RF planner
#                : True of the RF planning tool wizard has been opened.
# xem_sim_n not in pct
#
# 22 - xem_sim_n
#      Defined as: Axiem simulation count
#                : Number of Axiem simulations performed.
# xem_doc_b not in pct
#
# 23 - xem_doc_b
#      Defined as: Has Axiem document
#                : True if there is an Axiem document in project.
# ana_sim_n not in pct
#
# 24 - ana_sim_n
#      Defined as: Analyst simulation count
#                : Number of Analyst simulation.
# ana_doc_b not in pct
#
# 25 - ana_doc_b
#      Defined as: Has Analyst document
#                : True if project contains Analyst document
# tuning_b not in pct
#
# 26 - tuning_b
#      Defined as: Has Tuning
#                : True if tuning command has been executed.
# optim_b not in pct
#
# 27 - optim_b
#      Defined as: Has Optimization
#                : True of optimizer has been opened.
# yield_b not in pct
#
# 28 - yield_b
#      Defined as: Has Yield Analysis
#                : True if yield analysis command has been executed.
# extract_b not in pct
#
# 29 - extract_b
#      Defined as: Uses Extraction
#                : True if extract element exists and project contains an EM structure.
# annotation_b not in pct
#
# 30 - annotation_b
#      Defined as: Adding annotations
#                : True of a new annotation has been added.
# measurements_n not in pct
#
# 31 - measurements_n
#      Defined as: Distinct Measurements
#                : Number of unique measurements.
# lin_noise_b not in pct
#
# 32 - lin_noise_b
#      Defined as: Linear Noise
#                : True if a noise measurement (NF,Ci, RN, etc) is found.
# osc_b not in pct
#
# 33 - osc_b
#      Defined as: Oscillator Analysis
#                : True if oscillator measurement or element is found.
# stability_b not in pct
#
# 34 - stability_b
#      Defined as: Stability Analysis
#                : True if a stability measurement (B1, K, GAM_GP2, STAB_GP2, etc) is found.
# cell_stretchers_b not in pct
#
# 35 - cell_stretchers_b
#      Defined as: Cell Stretchers
#                : True if a cell stretcher command is found.
# antenna_b not in pct
#
# 36 - antenna_b
#      Defined as: Antennas
#                : True if an antenna measurement is found.
# ifilter_b not in pct
#
# 37 - ifilter_b
#      Defined as: iFilter Wizard
#                : True if the iFilter wizard is opened or edited.
# symbol_gen_b not in pct
#
# 38 - symbol_gen_b
#      Defined as: Symbol Generation Wizard
#                : True if the symbol wizard is opened or edited.
# create_process_b not in pct
#
# 39 - create_process_b
#      Defined as: Create new process
#                : True of the create new process command is executed.
# board_import_b not in pct
#
# 40 - board_import_b
#      Defined as: PCB Import
#                : True if any of the pcb import wizards are opened or edited.
# scripts_b not in pct
#
# 41 - scripts_b
#      Defined as: Uses standard scripts
#                : True if any script is executed.
# script_ide_b not in pct
#
# 42 - script_ide_b
#      Defined as: Scripting IDE
#                : True if the scripting editor is opened.
# bindkeys_b not in pct
#
# 43 - bindkeys_b
#      Defined as: Customize bindkeys
#                : True if the hotkey dialog is opened.
# layout_b not in pct
#
# 44 - layout_b
#      Defined as: Layout
#                : True if view layout, snap together or properties is executed (needs work).
# gen_poly_b not in pct
#
# 45 - gen_poly_b
#      Defined as: Generalized Polygons
#                : True if any generalized polygons commands are used.
# pdk_b not in pct
#
# 46 - pdk_b
#      Defined as: Use PDK
#                : True if any PDK exists.
# layout_checks_b not in pct
#
# 47 - layout_checks_b
#      Defined as: HichlightConnect connectivity checks
#                : True if any HighlightConnect Probe, Rule, Off or All exists.
# project_import_b not in pct
#
# 48 - project_import_b
#      Defined as: Project import
#                : True if project import is executed.
# enable_disable_b not in pct
#
# 49 - enable_disable_b
#      Defined as: Enable Disable Element
#                : True if any enable disable script is executed.
# markers_b not in pct
#
# 50 - markers_b
#      Defined as: Graph markers
#                : True if graph markers are used.
# switch_lists_b not in pct
#
# 51 - switch_lists_b
#      Defined as: Switch lists
#                : True if manage switch lists is opened.
# sim_filters_b not in pct
#
# 52 - sim_filters_b
#      Defined as: Simulation filters
#                : True if manage simulation filters command is executed.
# freeze_traces_b not in pct
#
# 53 - freeze_traces_b
#      Defined as: Freeze traces
#                : True if freeze traces is executed.
# schematic_eq_b not in pct
#
# 54 - schematic_eq_b
#      Defined as: Schematic equations
#                : True if insert equations is executed.
# output_eq_b not in pct
#
# 55 - output_eq_b
#      Defined as: Output equations
#                : True if output equation is added.
# add_mwo_elem_b not in pct
#
# 56 - add_mwo_elem_b
#      Defined as: Add MWO element
#                : True if a new MWO element has been added.
# add_vss_elem_b not in pct
#
# 57 - add_vss_elem_b
#      Defined as: Add VSS element
#                : True if a new MWO element has been added.
# add_sim_doc_b not in pct
#
# 58 - add_sim_doc_b
#      Defined as: Add Simulation Document
#                : True if a new simulation document has been added.
# add_measurement_b not in pct
#
# 59 - add_measurement_b
#      Defined as: Add measurement
#                : True if a new measurement has been added.
# user_folder_b not in pct
#
# 60 - user_folder_b
#      Defined as: Create user folder
#                : True of a new user folder was created.
# envelope_sim_b not in pct
#
# 61 - envelope_sim_b
#      Defined as: Envelope simulation
#                : True if Aplac co-sim simulation run and NS_S_ENV is present.
# drc_b not in pct
#
# 62 - drc_b
#      Defined as: DRC checks
#                : True if a drc clip area was inserted or if Design Rule Check is run.
# lvs_b not in pct
#
# 63 - lvs_b
#      Defined as: LVS checker
#                : True if a LVS output file is created or Load/Clear LVS Errors is executed.
# job_scheduler_b not in pct
#
# 64 - job_scheduler_b
#      Defined as: Job Scheduler
#                : True if the job scheduler status is displayed or js admin used.
# job_rich_text_b not in pct
#
# 65 - job_rich_text_b
#      Defined as: Rich Text
#                : True if rich text is used.
# pcb_point_ports_b not in pct
#
# 66 - pcb_point_ports_b
#      Defined as: PCB Point Ports
#                : True if InsertPointPort command used
# pcb_improved_clipping_b not in pct
#
# 67 - pcb_improved_clipping_b
#      Defined as: PCB Improved Clipping Algorithm
#                : True if PCB EM Setup or ProcessLib used
# pcb_shape_flow_b not in pct
#
# 68 - pcb_shape_flow_b
#      Defined as: PCB Shape Flow
#                : True if CopyToEmDocument is used
# network_synthesis_b not in pct
#
# 68 - network_synthesis_b
#      Defined as: Network Synthesis
#                : True if network synthesis wizard is used
# floating_load_pull_b not in pct
#
# 69 - floating_load_pull_b
#      Defined as: Floating load pull marker
#                : True if G_LPGG or GammaPts is used
# phased_array_b not in pct
#
# 70 - phased_array_b
#      Defined as: Phased Array
#                : True if phased array wizard is used
# doc_sets_b not in pct
#
# 71 - doc_sets_b
#      Defined as: Document Sets
#                : True if DOC_SET element is found.
# insert_window_b not in pct
#
# 72 - insert_window_b
#      Defined as: Insert Window
#                : True if InsertWindow command is used
# remote_axiem_n not in pct
#
# 73 - remote_axiem_n
#      Defined as: Remote Axiem
#                : Number of remote axiem jobs submitted
# remote_analyst_n not in pct
#
# 74 - remote_analyst_n
#      Defined as: Remote Analyst
#                : Number of remote analyst jobs submitted
# radar_b not in pct
#
# 75 - radar_b
#      Defined as: Has radar library elements
#                : True if any radar library model is found in the project.
