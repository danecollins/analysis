# %%
# Generic Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pylab
pylab.rcParams['figure.figsize'] = (12,8)  # set default plot size but not working below
# Out:
# /Users/dane/env/dt/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Notebook specific setup
datadir = '/Users/dane/data/a/tlm/features/'

# %%
fn = datadir + 'featured_user_weeks.csv'
print('reading', fn)
df = pd.read_csv(fn, encoding='latin1')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.iloc[0]
# Out:
# reading /Users/dane/data/a/tlm/features/featured_user_weeks.csv
# HB_aplac_b                                                1
# HB_legacy_b                                               0
# add_measurement_b                                         1
# add_mwo_elem_b                                            1
# add_sim_doc_b                                             1
# add_vss_elem_b                                            0
# ana_doc_b                                                 1
# ana_sim_n                                                84
# annotation_b                                              0
# antenna_b                                                 0
# bindkeys_b                                                0
# board_import_b                                            0
# cell_stretchers_b                                         0
# commands_n                                             1973
# company                    National Instruments - AWR Group
# create_process_b                                          1
# disp_name                                    Christian Bean
# doc_sets_b                                                0
# drc_b                                                     0
# ele_created_n                                           143
# em_sim_b                                                  1
# ems_doc_b                                                 0
# ems_highcnt_b                                             1
# ems_sim_n                                              1282
# enable_disable_b                                          1
# envelope_sim_b                                            1
# extract_b                                                 1
# floating_load_pull_b                                      0
# freeze_traces_b                                           0
# gen_poly_b                                                0
#                                          ...
# pcb_improved_clipping_b                                   0
# pcb_point_ports_b                                         0
# pcb_shape_flow_b                                          0
# pdk_b                                                     0
# phased_array_b                                            0
# project_import_b                                          1
# schematic_eq_b                                            0
# script_ide_b                                              0
# scripts_b                                                 1
# sim_filters_b                                             0
# stability_b                                               0
# switch_lists_b                                            0
# symbol_gen_b                                              0
# transient_b                                               0
# tuning_b                                                  0
# user_folder_b                                             0
# user_id                                                 190
# user_type                                          internal
# vss_doc_b                                                 1
# vss_rfb_b                                                 0
# vss_rfi_b                                                 0
# vss_rfp_b                                                 0
# vss_sim_n                                                 3
# week                                                    644
# xem_doc_b                                                 0
# xem_sim_n                                                 0
# xmodels_b                                                 1
# yield_b                                                   0
# activity                                           0.958537
# scope                                               36.2319
# Name: 0, Length: 80, dtype: object

# %%
# reorder columns
cols = df.columns.tolist()
cols.insert(0, cols.pop(cols.index('company')))
cols.insert(0, cols.pop(cols.index('user_type')))
cols.insert(0, cols.pop(cols.index('disp_name')))
cols.insert(0, cols.pop(cols.index('week')))
df = df[cols]
df.iloc[0]
# Out:
# week                                                    644
# disp_name                                    Christian Bean
# user_type                                          internal
# company                    National Instruments - AWR Group
# HB_aplac_b                                                1
# HB_legacy_b                                               0
# add_measurement_b                                         1
# add_mwo_elem_b                                            1
# add_sim_doc_b                                             1
# add_vss_elem_b                                            0
# ana_doc_b                                                 1
# ana_sim_n                                                84
# annotation_b                                              0
# antenna_b                                                 0
# bindkeys_b                                                0
# board_import_b                                            0
# cell_stretchers_b                                         0
# commands_n                                             1973
# create_process_b                                          1
# doc_sets_b                                                0
# drc_b                                                     0
# ele_created_n                                           143
# em_sim_b                                                  1
# ems_doc_b                                                 0
# ems_highcnt_b                                             1
# ems_sim_n                                              1282
# enable_disable_b                                          1
# envelope_sim_b                                            1
# extract_b                                                 1
# floating_load_pull_b                                      0
#                                          ...
# osc_b                                                     0
# output_eq_b                                               0
# pcb_improved_clipping_b                                   0
# pcb_point_ports_b                                         0
# pcb_shape_flow_b                                          0
# pdk_b                                                     0
# phased_array_b                                            0
# project_import_b                                          1
# schematic_eq_b                                            0
# script_ide_b                                              0
# scripts_b                                                 1
# sim_filters_b                                             0
# stability_b                                               0
# switch_lists_b                                            0
# symbol_gen_b                                              0
# transient_b                                               0
# tuning_b                                                  0
# user_folder_b                                             0
# user_id                                                 190
# vss_doc_b                                                 1
# vss_rfb_b                                                 0
# vss_rfi_b                                                 0
# vss_rfp_b                                                 0
# vss_sim_n                                                 3
# xem_doc_b                                                 0
# xem_sim_n                                                 0
# xmodels_b                                                 1
# yield_b                                                   0
# activity                                           0.958537
# scope                                               36.2319
# Name: 0, Length: 80, dtype: object

# %%
demo = df[df.user_type=='demo']
fig = plt.gcf()
fig.set_size_inches(18,12)
plt.scatter(demo.activity, demo.scope)

# %%
fig = plt.gcf()
fig.set_size_inches(18,12)
plt.hist(demo.scope)
# Out:
# (array([636., 812., 907., 525., 533., 259., 121.,  61.,  26.,  10.]),
#  array([ 0.        ,  5.36231884, 10.72463768, 16.08695652, 21.44927536,
#         26.8115942 , 32.17391304, 37.53623188, 42.89855072, 48.26086957,
#         53.62318841]),
#  <a list of 10 Patch objects>)
